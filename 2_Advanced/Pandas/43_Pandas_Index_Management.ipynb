# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

#loading data
dataset = load_dataset('coachprerakmehta/data_jobs')
df = dataset['train'].to_pandas()

#data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#        job_title_short                                          job_title  \
# 752574    Data Analyst                           Data Analyst - Part-time
# 504034    Data Analyst                                Beauty Data Analyst
# 758852  Data Scientist                                     Data Scientist
# 328504    Data Analyst                     Manager Data Analysis - Remote
# 631959    Data Analyst  Data & Reporting Analyst, Project Management T...
#
#                 job_location            job_via job_schedule_type  \
# 752574         Charlotte, NC       via Snagajob         Part-time
# 504034                 China             via 领英         Full-time
# 758852            Remote, OR         via Indeed         Full-time
# 328504              Anywhere  via CareerBuilder         Full-time
# 631959  Cluj-Napoca, Romania       via LinkedIn         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# ...

# %%
df.index.name = 'job_index'
df.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# job_index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# ...

# %%
df.sample(5)
# Out:
#                      job_title_short              job_title  \
# job_index
# 24394           Senior Data Engineer   Senior Data Engineer
# 368495                 Data Engineer          Data Engineer
# 749354                  Data Analyst  Research Data Analyst
# 364933                  Data Analyst       Sr. Data Analyst
# 429999     Machine Learning Engineer   Automation  Engineer
#
#                 job_location                       job_via job_schedule_type  \
# job_index
# 24394                Ireland                  via LinkedIn         Full-time
# 368495        Granada, Spain                     via BeBee         Full-time
# 749354          Evanston, IL                  via LinkedIn         Full-time
# 364933           Chicago, IL  via My Champlain Valley Jobs         Full-time
# 429999     Bangkok, Thailand               via Trabajo.org         Full-time
#
#            job_work_from_home          search_location     job_posted_date  \
# job_index
# ...

# %% [markdown]
# Resetting index:

# %%
#creating a new dataframe based on job_country = USA
df_usa = df[df['job_country'] == "United States"]
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
df_usa.reset_index(inplace=True)
df_usa
# Out:
#          index  job_index       job_title_short  \
# 0            0          0  Senior Data Engineer
# 1            1          3         Data Engineer
# 2            2          5         Data Engineer
# 3            3          6  Senior Data Engineer
# 4            4          9        Data Scientist
# ...        ...        ...                   ...
# 206287  206287     785673        Data Scientist
# 206288  206288     785685          Data Analyst
# 206289  206289     785692        Data Scientist
# 206290  206290     785703          Data Analyst
# 206291  206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# ...

# %% [markdown]
# set index:

# %%
df_usa.set_index('job_index', inplace=True)      #setting the original index value

# %%
df_usa
# Out:
#             index       job_title_short  \
# job_index
# 0               0  Senior Data Engineer
# 3               1         Data Engineer
# 5               2         Data Engineer
# 6               3  Senior Data Engineer
# 9               4        Data Scientist
# ...           ...                   ...
# 785673     206287        Data Scientist
# 785685     206288          Data Analyst
# 785692     206289        Data Scientist
# 785703     206290          Data Analyst
# 785705     206291          Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# ...

# %%
median_pivot = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=['median', 'min', 'max'])
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0         16500.0        387460.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Senior Data Scientist            155500.0         45000.0        890000.0
# Software Engineer                 99150.0         28000.0        375000.0

# %%
median_pivot.sort_values(by=('median', 'salary_year_avg'), ascending=False)      #2 level of sorting -> MEDIAN of SALARY_YEAR_AVG
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Senior Data Scientist            155500.0         45000.0        890000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Software Engineer                 99150.0         28000.0        375000.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Business Analyst                  85000.0         16500.0        387460.0

# %%
median_pivot.sort_index(inplace=True)     #sorting the job_title_short column
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  85000.0         16500.0        387460.0
# Cloud Engineer                    90000.0         42000.0        280000.0
# Data Analyst                      90000.0         25000.0        650000.0
# Data Engineer                    125000.0         15000.0        525000.0
# Data Scientist                   127500.0         27000.0        960000.0
# Machine Learning Engineer        106415.0         30000.0        325000.0
# Senior Data Analyst              111175.0         30000.0        425000.0
# Senior Data Engineer             147500.0         35000.0        425000.0
# Senior Data Scientist            155500.0         45000.0        890000.0
# Software Engineer                 99150.0         28000.0        375000.0
