# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

#loading data
dataset = load_dataset('coachprerakmehta/data_jobs')
df = dataset['train'].to_pandas()

#data cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
#provides random number of sample data from the dataframe
df.sample(10, random_state=50)     #42 is just an integer
# Out:
#                   job_title_short  \
# 635132               Data Analyst
# 103229             Data Scientist
# 276345             Data Scientist
# 233302              Data Engineer
# 137740  Machine Learning Engineer
# 289887               Data Analyst
# 129795             Data Scientist
# 119168             Data Scientist
# 440548             Data Scientist
# 265968             Data Scientist
#
#                                            job_title  \
# 635132                                  Data Analyst
# 103229  Data Scientist ( consumer-facing technology)
# 276345         Data Visulization-power Bi,sql&python
# 233302         Data Engineer - Full-time / Part-time
# 137740      Junior Machine Learning Cloud Operations
# 289887                           Master Data Analyst
# 129795                          Senior Data Modeller
# 119168                                Data Scientist
# 440548                            data scientist f/h
# ...

# %%
#loading data
dataset = load_dataset('coachprerakmehta/data_jobs')
df_original = dataset['train'].to_pandas()

df_altered = df_original.copy()     #The two data frames have different id() and changes in either of two will not be reflected in the other.

# %%
print('Id of df_altered = ', id(df_altered))
print('Id of df_original = ', id(df_original))
print('Are the two ids same? ', id(df_original) == id(df_altered))
# Out:
# Id of df_altered =  1994282139408
# Id of df_original =  1993107866256
# Are the two ids same?  False

# %%
#calculating median salary
median_salary_year = df['salary_year_avg'].median()

#Filling NaN values with median_salary_year
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary_year)
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
